# %%
import sys
sys.path.append('../modules')
from wrangling import wrangling_valores as wr
from grafo_estacionalidad import Grafo_Estacionalidad

wr()

# %%
x = Grafo_Estacionalidad(wr(), 'v_x')

m = Grafo_Estacionalidad(wr(), 'v_m')

x.set_title('Valores de exportación - Enero 2011 a Febrero 2022')
x.set_size(20,15)
x.hacer_grafo()
x.set_ylabel('Valor en millones de dólares')

m.set_title('Valores de importación - Enero 2011 a Febrero 2022')
m.set_size(20,15)
m.set_colors(('green', 'darkblue'))
m.hacer_grafo()
m.set_ylabel('Valor en millones de dólares')



x.print('../output/Expo_estacional_actualizada_feb22.pdf')
m.print('../output/Impo_estacional_actualizada_feb22.pdf')
